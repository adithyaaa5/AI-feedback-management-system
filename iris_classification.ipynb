# %% [markdown]
# <a href="https://colab.research.google.com/github/adithyaaa5/AI-feedback-management-system/blob/main/iris_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
iris= load_iris()
x= iris.data
y=iris.target

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3)
model.fit(x_train, y_train)

y_pred= model.predict(x_test)
print(y_pred[:10])

print(y_test[:10])

from sklearn.metrics import accuracy_score
accuracy= accuracy_score (y_test, y_pred)
print("Accuracy: ", accuracy)

print(iris.target_names)
print(x[:5])
print(y[:5])

import numpy as np
print(np.bincount(y))

import pandas as pd
df=pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)
df['species']=iris.target
print(df.head())

df.describe()

import matplotlib.pyplot as plt
plt.scatter(
    x[:, 2],
    x[:, 3],
    c=y
)

plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.title("Iris Dataset")

plt.show()

print(iris.target_names)
for i in range(5):
    print(x[i], iris.target_names[y[i]])


new_flower = [[5.0, 3.4, 1.5, 0.2]]

prediction = model.predict(new_flower)

print(prediction)
print(iris.target_names[prediction[0]])
# Out:
# [1 0 2 1 1 0 1 2 1 1]
# [1 0 2 1 1 0 1 2 1 1]
# Accuracy:  1.0
# ['setosa' 'versicolor' 'virginica']
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# [0 0 0 0 0]
# [50 50 50]
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ['setosa' 'versicolor' 'virginica']
# [5.1 3.5 1.4 0.2] setosa
# [4.9 3.  1.4 0.2] setosa
# [4.7 3.2 1.3 0.2] setosa
# [4.6 3.1 1.5 0.2] setosa
# [5.  3.6 1.4 0.2] setosa
# [0]
# setosa
